# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 畫出 histogram 和 normal distribution (常態分佈) 曲線
#
# 參考資料： <br>
# numpy.random.normal <br>
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
mu = 20    # 平均值
sigma = 100  # 標準差
size = 1000  # 樣本數

x = np.random.normal(mu, sigma, size)

count, bins, ignored = plt.hist(x, 10, density=True,color="c")   # 傳回 count, bins, ignored

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
         np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=5, color='m')   ##　常態分布曲線方程式

plt.show()

# %%
print(count,bins,ignored)
# Out:
# [1.80375250e-04 6.55910001e-04 1.83654800e-03 3.13197025e-03
#  4.01744876e-03 3.49272076e-03 1.88574125e-03 9.01876251e-04
#  2.29568500e-04 6.55910001e-05] [-253.64708291 -192.66310654 -131.67913018  -70.69515382   -9.71117745
#    51.27279891  112.25677528  173.24075164  234.224728    295.20870437
#   356.19268073] <BarContainer object of 10 artists>

# %%
mu = 20    # 平均值
sigma = 100  # 標準差
size = 1000  # 樣本數

x = np.random.normal(mu, sigma, size)

count, bins, ignored = plt.hist(x, 20, density=True,color="lightgreen")   # 傳回 count, bins, ignored

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
         np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=5, color='orange')   ##　常態分布曲線方程式

plt.show()

# %%
x = np.random.randint(1000, size=10)
y = np.random.randint(1000, size=10)
plt.bar(x, y, tick_label=['A','B','C','D','E','F','G','H','I','J'])
plt.show()

# %%
xx=np.random.normal(10,20,1000)
plt.hist(xx,bins=15)
plt.show()

# %%
plt.hist(y)
plt.show()

# %%
plt.hist(x, bins="auto")  ## auto 組距 自動
plt.show()

# %%
z = np.random.randn(10000)

# %%
plt.hist(z, bins=40)
plt.show()

# %%
plt.hist(z, bins='auto',density=True)   ## 機率密度
plt.show()

# %%
import matplotlib.pyplot as plt    # 載入 matplotlib.pyplot
import numpy as np    # 載入 numpy

mu = 0    # 平均值
sigma = 0.1  # 標準差
size = 1000  # 樣本數

x = np.random.normal(mu, sigma, size)

count, bins, ignored = plt.hist(x, 30, density=True)   # 傳回 count, bins, ignored

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
         np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')

plt.show()
